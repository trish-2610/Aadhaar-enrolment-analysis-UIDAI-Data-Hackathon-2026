# %% [markdown]
# # Data Cleaning and Preprocessing

# %% [markdown]
# ## Step 1 : Load the dataset

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("dataset/aadhar_dataset.csv")
df.head()
# Out:
#          date           state     district  pincode  age_0_5  age_5_17  \
# 0  01-09-2025  Madhya Pradesh   Agar Malwa   465447        3         0
# 1  01-09-2025  Madhya Pradesh    Alirajpur   457888        7        11
# 2  01-09-2025  Madhya Pradesh      Anuppur   484113        1         0
# 3  01-09-2025  Madhya Pradesh      Anuppur   484440        1         0
# 4  01-09-2025  Madhya Pradesh  Ashok Nagar   473330       19         4
#
#    age_18_greater
# 0               0
# 1               0
# 2               0
# 3               0
# 4               0

# %% [markdown]
# ## Step 2 : Renaming age group columns

# %%
df = df.rename(columns={
    'age_0_5' : 'age_group_0_to_5',
    'age_5_17' : 'age_group_5_to_17',
    'age_18_greater' : 'age_group_18_plus'
})
df.head()
# Out:
#          date           state     district  pincode  age_group_0_to_5  \
# 0  01-09-2025  Madhya Pradesh   Agar Malwa   465447                 3
# 1  01-09-2025  Madhya Pradesh    Alirajpur   457888                 7
# 2  01-09-2025  Madhya Pradesh      Anuppur   484113                 1
# 3  01-09-2025  Madhya Pradesh      Anuppur   484440                 1
# 4  01-09-2025  Madhya Pradesh  Ashok Nagar   473330                19
#
#    age_group_5_to_17  age_group_18_plus
# 0                  0                  0
# 1                 11                  0
# 2                  0                  0
# 3                  0                  0
# 4                  4                  0

# %% [markdown]
# ## Step 3 : Remove unnecessary column

# %%
df = df.drop(columns=['pincode'])
df.head()
# Out:
#          date           state     district  age_group_0_to_5  \
# 0  01-09-2025  Madhya Pradesh   Agar Malwa                 3
# 1  01-09-2025  Madhya Pradesh    Alirajpur                 7
# 2  01-09-2025  Madhya Pradesh      Anuppur                 1
# 3  01-09-2025  Madhya Pradesh      Anuppur                 1
# 4  01-09-2025  Madhya Pradesh  Ashok Nagar                19
#
#    age_group_5_to_17  age_group_18_plus
# 0                  0                  0
# 1                 11                  0
# 2                  0                  0
# 3                  0                  0
# 4                  4                  0

# %% [markdown]
# ## Step 4 : Convert date column to datetime (Changing Datatype)

# %%
df['date'] = pd.to_datetime(df['date'] , format="%d-%m-%Y")
print(df.dtypes)
# Out:
# date                 datetime64[ns]
# state                        object
# district                     object
# age_group_0_to_5              int64
# age_group_5_to_17             int64
# age_group_18_plus             int64
# dtype: object

# %% [markdown]
# ## Step 5 : Clean text fields (state and district)

# %%
df['state'] = df['state'].str.strip()
df['district'] = df['district'].str.strip()

# %% [markdown]
# ## Step 6 : Checking Null Values

# %%
df.isnull().sum()
# Out:
# date                 0
# state                0
# district             0
# age_group_0_to_5     0
# age_group_5_to_17    0
# age_group_18_plus    0
# dtype: int64

# %% [markdown]
# #### Data is already cleaned

# %% [markdown]
# ## Step 7 : Summary of the dataset

# %%
df.describe()
# Out:
#                                 date  age_group_0_to_5  age_group_5_to_17  \
# count                          59991      59991.000000       59991.000000
# mean   2025-10-10 02:11:28.063209472          6.959261           2.514160
# min              2025-03-09 00:00:00          0.000000           0.000000
# 25%              2025-09-12 00:00:00          1.000000           0.000000
# 50%              2025-10-20 00:00:00          3.000000           1.000000
# 75%              2025-11-14 00:00:00          7.000000           2.000000
# max              2026-01-03 00:00:00       1400.000000        1376.000000
# std                              NaN         22.971808          16.253868
#
#        age_group_18_plus
# count       59991.000000
# mean            0.182911
# min             0.000000
# 25%             0.000000
# 50%             0.000000
# 75%             0.000000
# max           103.000000
# std             1.737969

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ## Total enrolments

# %%
df['total_enrolments'] = (
    df['age_group_0_to_5'] + df['age_group_5_to_17'] + df['age_group_18_plus']
)
df['total_enrolments'].head()
# Out:
# 0     3
# 1    18
# 2     1
# 3     1
# 4    23
# Name: total_enrolments, dtype: int64

# %% [markdown]
# ## Age group contribution ratios

# %%
df['pct_age_0_to_5'] = df['age_group_0_to_5'] / df['total_enrolments']
df['pct_age_5_to_17'] = df['age_group_5_to_17'] / df['total_enrolments']
df['pct_age_18_plus'] = df['age_group_18_plus'] / df['total_enrolments']

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## State-level aggregation

# %%
state_level = df.groupby('state', as_index=False).agg({
    'age_group_0_to_5': 'sum',
    'age_group_5_to_17': 'sum',
    'age_group_18_plus': 'sum',
    'total_enrolments': 'sum'
})
state_level
# Out:
#             state  age_group_0_to_5  age_group_5_to_17  age_group_18_plus  \
# 0  Madhya Pradesh            417493             150827              10973
#
#    total_enrolments
# 0            579293

# %% [markdown]
# ## District-level aggregation

# %%
district_level = df.groupby(
    ['state', 'district'], as_index=False).agg({'total_enrolments' : 'sum'})
district_level.head()
# Out:
#             state     district  total_enrolments
# 0  Madhya Pradesh   Agar Malwa              3195
# 1  Madhya Pradesh    Alirajpur              7705
# 2  Madhya Pradesh      Anuppur              3951
# 3  Madhya Pradesh  Ashok Nagar              6144
# 4  Madhya Pradesh   Ashoknagar              3011

# %% [markdown]
# ## Saving our Cleaned dataset

# %% [markdown]
# #### Cleaned and preprocessed UIDAI Aadhaar dataset

# %%
df.to_csv("aadhaar_cleaned_dataset.csv" , index=False)

# %% [markdown]
# #### State-level aggregated dataset

# %%
state_level.to_csv("aadhaar_state_level_summary.csv" , index=False)

# %% [markdown]
# #### District-level aggregated dataset

# %%
district_level.to_csv("aadhaar_district_level_summary.csv", index=False)
